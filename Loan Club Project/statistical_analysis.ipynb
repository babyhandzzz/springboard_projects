# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import chi2
pd.options.display.float_format = '{:.4f}'.format

# %% [markdown]
# Loading the data

# %%
df = pd.read_csv('Data/Binary_label_K_bins_train.csv')
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
y = df[['training labels']]
X = df.drop('training labels',axis='columns')

# %%
scores, pvalues = chi2(X, y)

# %%
p_vals = pd.DataFrame(X.columns,columns=['features'])

# %%
p_vals['p-values'] = pvalues

# %%
p_vals.dropna(inplace=True)

# %%
p_vals.sort_values('p-values')
# Out:
#                              features  p-values
# 103                      sub_grade_B3    0.0000
# 79                            grade_A    0.0000
# 80                            grade_B    0.0000
# 82                            grade_D    0.0000
# 83                            grade_E    0.0000
# 84                            grade_G    0.0000
# 85                       sub_grade_A1    0.0000
# 87                       sub_grade_A5    0.0000
# 92                       sub_grade_A2    0.0000
# 93                       sub_grade_B1    0.0000
# 94                       sub_grade_D2    0.0000
# 95                       sub_grade_B2    0.0000
# 96                       sub_grade_E5    0.0000
# 97                    sub_grade_other    0.0000
# 98                       sub_grade_D3    0.0000
# 99                       sub_grade_D5    0.0000
# 100                      sub_grade_D1    0.0000
# 101                      sub_grade_D4    0.0000
# 105                      sub_grade_E4    0.0000
# 106                      sub_grade_E1    0.0000
# 107                      sub_grade_A4    0.0000
# 108                      sub_grade_E3    0.0000
# 109                      sub_grade_A3    0.0000
# 122                  emp_length_other    0.0000
# 123               home_ownership_RENT    0.0000
# 125           home_ownership_MORTGAGE    0.0000
# 128  verification_status_Not Verified    0.0000
# 129      verification_status_Verified    0.0000
# 78                    term_ 36 months    0.0000
# 74                    tot_hi_cred_lim    0.0000
# 175            debt_settlement_flag_N    0.0000
# 43                        avg_cur_bal    0.0000
# 44                     bc_open_to_buy    0.0000
# 42               acc_open_past_24mths    0.0000
# 26                        tot_cur_bal    0.0000
# 3                            int_rate    0.0000
# 6                                 dti    0.0000
# 8                      inq_last_6mths    0.0000
# 22                    last_pymnt_amnt    0.0000
# 52                           mort_acc    0.0000
# 15                        total_pymnt    0.0000
# 17                    total_rec_prncp    0.0000
# 16                    total_pymnt_inv    0.0000
# 76                     total_bc_limit    0.0000
# 71                   percent_bc_gt_75    0.0000
# 130               purpose_credit_card    0.0000
# 69                 num_tl_op_past_12m    0.0000
# 18                      total_rec_int    0.0000
# 89                       sub_grade_C5    0.0000
# 53               mths_since_recent_bc    0.0000
# 51                     mo_sin_rcnt_tl    0.0000
# 81                            grade_C    0.0000
# 139          title_Debt consolidation    0.0000
# 50              mo_sin_rcnt_rev_tl_op    0.0000
# 104                      sub_grade_B4    0.0000
# 38                   total_rev_hi_lim    0.0000
# 58                    num_actv_rev_tl    0.0000
# 88                       sub_grade_C4    0.0000
# 1                         funded_amnt    0.0000
# 0                           loan_amnt    0.0000
# 136            purpose_small_business    0.0000
# 64                num_rev_tl_bal_gt_0    0.0000
# 2                     funded_amnt_inv    0.0000
# 137     title_Credit card refinancing    0.0000
# 45                            bc_util    0.0000
# 5                          annual_inc    0.0000
# 54              mths_since_recent_inq    0.0000
# 13                         revol_util    0.0000
# 4                         installment    0.0000
# 132        purpose_debt_consolidation    0.0000
# 140                       title_other    0.0000
# 49               mo_sin_old_rev_tl_op    0.0000
# 86                       sub_grade_B5    0.0000
# 152                     addr_state_CO    0.0000
# 114              emp_length_10+ years    0.0000
# 160                     addr_state_WA    0.0000
# 158                     addr_state_OR    0.0000
# 102                      sub_grade_C3    0.0000
# 57                     num_actv_bc_tl    0.0000
# 159                     addr_state_NY    0.0000
# 134                       purpose_car    0.0000
# 131          purpose_home_improvement    0.0000
# 142          title_Debt Consolidation    0.0000
# 62                      num_op_rev_tl    0.0000
# 168                     addr_state_AL    0.0000
# 48                 mo_sin_old_il_acct    0.0000
# 144                     addr_state_FL    0.0000
# 165                     addr_state_LA    0.0000
# 166                     addr_state_SC    0.0000
# 138            title_Home improvement    0.0000
# 147                     addr_state_IL    0.0000
# 141                       title_Other    0.0000
# 10                           open_acc    0.0000
# 65                           num_sats    0.0000
# 133                     purpose_other    0.0000
# 151                     addr_state_GA    0.0000
# 90                       sub_grade_C1    0.0000
# 156                     addr_state_NV    0.0000
# 60                          num_bc_tl    0.0000
# 145                     addr_state_MD    0.0000
# 143                     addr_state_NJ    0.0000
# 70                     pct_tl_nvr_dlq    0.0000
# 171             initial_list_status_w    0.0000
# 59                        num_bc_sats    0.0000
# 161                     addr_state_IN    0.0000
# 124                home_ownership_OWN    0.0000
# 12                          revol_bal    0.0000
# 163                     addr_state_WI    0.0000
# 91                       sub_grade_C2    0.0000
# 135                   purpose_medical    0.0000
# 170                     addr_state_TN    0.0000
# 14                          total_acc    0.0000
# 146                     addr_state_CA    0.0000
# 119               emp_length_< 1 year    0.0001
# 157                     addr_state_MO    0.0004
# 162                     addr_state_NC    0.0004
# 117                emp_length_6 years    0.0005
# 150                     addr_state_PA    0.0005
# 164                     addr_state_MA    0.0018
# 153                     addr_state_OH    0.0022
# 75                  total_bal_ex_mort    0.0077
# 77         total_il_high_credit_limit    0.0116
# 111                 emp_title_Manager    0.0131
# 148                  addr_state_other    0.0184
# 118                emp_length_7 years    0.0310
# 61                          num_il_tl    0.0354
# 172       application_type_Individual    0.0524
# 113                emp_length_2 years    0.0669
# 112                emp_length_4 years    0.0761
# 167                     addr_state_MN    0.0764
# 121                emp_length_5 years    0.0893
# 155                     addr_state_MI    0.0910
# 149                     addr_state_AZ    0.1272
# 63                      num_rev_accts    0.1674
# 154                     addr_state_TX    0.3580
# 120                emp_length_9 years    0.5231
# 115                emp_length_8 years    0.5383
# 169                     addr_state_VA    0.6035
# 127              home_ownership_OTHER    0.7057
# 110                   emp_title_other    0.7924
# 126                home_ownership_ANY    0.8516
# 174          disbursement_method_Cash    0.9064
# 116                emp_length_3 years    0.9126
# 173                   hardship_flag_N    0.9984

# %%
p_vals.dropna(inplace=True)
# Out:
#           p-values
# 103   0.000000e+00
# 79    0.000000e+00
# 80    0.000000e+00
# 82    0.000000e+00
# 83    0.000000e+00
# 84    0.000000e+00
# 85    0.000000e+00
# 87    0.000000e+00
# 92    0.000000e+00
# 93    0.000000e+00
# 94    0.000000e+00
# 95    0.000000e+00
# 96    0.000000e+00
# 97    0.000000e+00
# 98    0.000000e+00
# 99    0.000000e+00
# 100   0.000000e+00
# 101   0.000000e+00
# 105   0.000000e+00
# 106   0.000000e+00
# 107   0.000000e+00
# 108   0.000000e+00
# 109   0.000000e+00
# 122   0.000000e+00
# 123   0.000000e+00
# 125   0.000000e+00
# 128   0.000000e+00
# 129   0.000000e+00
# 78    0.000000e+00
# 74    0.000000e+00
# 175   0.000000e+00
# 43    0.000000e+00
# 44    0.000000e+00
# 42    0.000000e+00
# 26    0.000000e+00
# 3     0.000000e+00
# 6     0.000000e+00
# 8     0.000000e+00
# 22    0.000000e+00
# 52    0.000000e+00
# 15    0.000000e+00
# 17    0.000000e+00
# 16    0.000000e+00
# 76   2.318702e-289
# 71   7.500683e-279
# 130  1.040828e-275
# 69   1.860665e-257
# 18   6.251657e-255
# 89   1.330324e-236
# 53   6.405629e-228
# 51   9.356589e-226
# 81   1.077302e-221
# 139  2.484222e-220
# 50   3.223925e-219
# 104  1.723843e-207
# 38   5.614438e-185
# 58   3.022845e-171
# 88   3.276307e-167
# 1    2.105446e-166
# 0    2.804808e-166
# 136  1.039855e-161
# 64   2.432337e-161
# 2    2.977659e-159
# 137  4.609215e-150
# 45   3.084306e-148
# 5    4.500896e-144
# 54   1.070914e-141
# 13   1.331220e-125
# 4    4.481571e-109
# 132  4.038394e-107
# 140   3.410865e-99
# 49    2.293234e-95
# 86    2.834832e-90
# 152   4.047886e-64
# 114   1.835483e-60
# 160   5.644298e-55
# 158   7.880767e-55
# 102   6.562628e-52
# 57    5.290317e-48
# 159   3.238664e-47
# 134   3.426800e-44
# 131   1.251477e-42
# 142   2.482925e-42
# 62    8.971314e-35
# 168   6.896043e-26
# 48    2.085170e-25
# 144   1.218617e-24
# 165   1.764106e-21
# 166   2.038616e-21
# 138   5.180490e-21
# 147   3.389383e-19
# 141   5.478005e-19
# 10    4.493744e-18
# 65    1.162588e-16
# 133   4.644145e-13
# 151   6.661886e-12
# 90    5.314407e-11
# 156   2.330341e-10
# 60    7.369207e-10
# 145   1.483749e-09
# 143   5.985718e-09
# 70    1.348001e-08
# 171   1.618209e-08
# 59    7.088271e-08
# 161   1.057787e-07
# 124   1.230874e-07
# 12    1.989412e-07
# 163   4.910612e-07
# 91    1.394319e-06
# 135   1.905785e-06
# 170   4.333539e-06
# 14    1.165149e-05
# 146   3.879540e-05
# 119   1.151232e-04
# 157   3.995570e-04
# 162   4.348699e-04
# 117   5.165060e-04
# 150   5.322821e-04
# 164   1.825925e-03
# 153   2.234659e-03
# 75    7.720131e-03
# 77    1.163816e-02
# 111   1.313297e-02
# 148   1.835008e-02
# 118   3.104720e-02
# 61    3.536253e-02
# 172   5.240045e-02
# 113   6.689640e-02
# 112   7.610149e-02
# 167   7.642260e-02
# 121   8.928369e-02
# 155   9.096306e-02
# 149   1.271982e-01
# 63    1.674107e-01
# 154   3.579722e-01
# 120   5.230897e-01
# 115   5.383412e-01
# 169   6.034580e-01
# 127   7.056732e-01
# 110   7.924076e-01
# 126   8.516149e-01
# 174   9.064189e-01
# 116   9.126136e-01
# 173   9.983943e-01
